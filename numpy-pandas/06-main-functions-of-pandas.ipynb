# %%
import pandas as pd
df_book = pd.read_csv('../files/best-sellers.csv')

# %%
#df_book.head(3) #Return the first records
#df_book.tail(3) #Return the last records
#df_book.info()
#df_book.describe() #Statistics values of numeric columns
#df_book.memory_usage(deep=True) #How much memory do you use in your dataFrame, by column
df_book['Author'].value_counts() #Group by different values
# Out:
# Author
# Jeff Kinney                           12
# Gary Chapman                          11
# Rick Riordan                          11
# Suzanne Collins                       11
# American Psychological Association    10
#                                       ..
# Keith Richards                         1
# Chris Cleave                           1
# Alice Schertle                         1
# Celeste Ng                             1
# Adam Gasiewski                         1
# Name: count, Length: 248, dtype: int64

# %%
#df_book = pd.concat([df_book,df_book.iloc[0]]) #Doubling the first value
# df_book.drop_duplicates() #To delete doubling data
df_book.drop_duplicates(keep='Lata') #To delete the first doubling data

# %%
df_book.sort_values('Year', ascending=False)
# Out:
#                                                           Name  \
# 549          You Are a Badass: How to Stop Doubting Your Gr...
# 294          School Zone - Big Preschool Workbook - Ages 4 ...
# 489                           The Wonderful Things You Will Be
# 263            P is for Potty! (Sesame Street) (Lift-the-Flap)
# 130          Girl, Wash Your Face: Stop Believing the Lies ...
# ...                                                        ...
# User Rating                                                NaN
# Reviews                                                    NaN
# Price                                                      NaN
# Year                                                       NaN
# Genre                                                      NaN
#
#                             Author  User Rating  Reviews  Price    Year  \
# 549                    Jen Sincero          4.7  14331.0    8.0  2019.0
# ...
