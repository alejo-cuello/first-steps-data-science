# %%
import pandas as pd

# %%
dataFrame_book = pd.read_csv('../files/best-sellers.csv',sep=',',header=0,names=['Nombre', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre']) #If the file doesn't have header, complete with None
dataFrame_book
# Out:
#                                                 Nombre  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
pd.read_json('../files/hp-characters.json',typ='series')
# Out:
# 0       {'Name': 'Mrs. Abbott', 'Link': 'https://www.h...
# 1       {'Name': 'Hannah Abbott', 'Link': 'https://www...
# 2       {'Name': 'Abel Treetops', 'Link': 'https://www...
# 3       {'Name': 'Euan Abercrombie', 'Link': 'https://...
# 4       {'Name': 'Aberforth Dumbledore', 'Link': 'http...
#                               ...
# 1935    {'Name': 'Georgi Zdravko', 'Link': 'https://ww...
# 1936    {'Name': 'Zograf', 'Link': 'https://www.hp-lex...
# 1937    {'Name': 'Zonko', 'Link': 'https://www.hp-lexi...
# 1938    {'Name': 'Valentina Vázquez', 'Link': 'https:/...
# 1939    {'Name': 'Zygmunt Budge', 'Link': 'https://www...
# Length: 1940, dtype: object

# %% [markdown]
# Visit kaggle to download more dataframes!

# %% [markdown]
# How to filter by columns

# %%
sliced_frame = dataFrame_book[0:4]
sliced_frame[['Nombre','Author','Year']]
# Out:
#                                     Nombre              Author  Year
# 0            10-Day Green Smoothie Cleanse            JJ Smith  2016
# 1                        11/22/63: A Novel        Stephen King  2011
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson  2018
# 3                   1984 (Signet Classics)       George Orwell  2017

# %% [markdown]
# Loc uses labels, Iloc uses índices

# %%
sliced_frame.loc[0:3, ['Nombre','Author']] #This function includes the last index
# Out:
#                                     Nombre              Author
# 0            10-Day Green Smoothie Cleanse            JJ Smith
# 1                        11/22/63: A Novel        Stephen King
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson
# 3                   1984 (Signet Classics)       George Orwell

# %%
dataFrame_book.loc[:, ['Reviews']] * -1
# Out:
#      Reviews
# 0     -17350
# 1      -2052
# 2     -18979
# 3     -21424
# 4      -7665
# ..       ...
# 545    -9413
# 546   -14331
# 547   -14331
# 548   -14331
# 549   -14331
#
# [550 rows x 1 columns]

# %%
dataFrame_book.loc[:, ['Author']] == 'JJ Smith'
# Out:
#      Author
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# ..      ...
# 545   False
# 546   False
# 547   False
# 548   False
# 549   False
#
# [550 rows x 1 columns]

# %%
#dataFrame_book.iloc[:,0:2] #The second parameter indicates the columns
#dataFrame_book.iloc[:,3] * -1
dataFrame_book.iloc[:2,2:]
# Out:
#    User Rating  Reviews  Price  Year        Genre
# 0          4.7    17350      8  2016  Non Fiction
# 1          4.6     2052     22  2011      Fiction
