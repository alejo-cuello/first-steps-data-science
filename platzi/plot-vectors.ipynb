# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
v1 = np.array([2,5])
v2 = np.array([3,2])

# %%
# %run "utils/plot-vectors.ipynb"

# %%
plot_vectors([v1,v2], ['orange','blue'])
plt.xlim(-1,8)
plt.ylim(-1,8)
# Out:
# (-1.0, 8.0)
