# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# A linear combination is the sum of the multiplications of a vector with a number

# %%
# %run "utils/plot-vectors.ipynb"

# %%
v1 = np.array([2,5])
v2 = np.array([3,2])

v1v2 = 2*v1 + v2
print(v1v2)
# Out:
# [ 7 12]

# %%
plot_vectors([v1,v2,v1v2],["orange","blue","red"])
plt.xlim(-1,8)
plt.ylim(-1,12)
# Out:
# (-1.0, 12.0)

# %%
for a in range(-10,10): #Plotting all possible linear combinations of v1 and v2
    for b in range(-10,10):
        plt.scatter(v1[0]*a + v2[0]*b, v1[1]*a + v2[1]*b, marker='.', color='purple')
        
plt.axvline(x=0, color='grey')
plt.axhline(y=0, color='grey')
