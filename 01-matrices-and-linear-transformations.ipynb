# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# We can think about matrices as a linear transformations to vectors or spaces

# %%
A = np.array([[-1,3],[2,-2]])
vector = np.array([[2],[1]])

# %%
# %run "utils/plot-vectors.ipynb"

# %%
print(vector)
print(vector.flatten()) # Its useful for working with ML Algorithms and images

print(A)
print(A.flatten())
# Out:
# [[2]
#  [1]]
# [2 1]
# [[-1  3]
#  [ 2 -2]]
# [-1  3  2 -2]

# %%
plot_vectors([vector.flatten()], "blue")
plt.xlim(-0.5, 3)
plt.ylim(-0.5, 2)
# Out:
# [2 1]
# (-0.5, 2.0)

# %%
transformed_vector = A.dot(vector)
print(transformed_vector)
# Out:
# [[1]
#  [2]]

# %%
plot_vectors([vector.flatten(), transformed_vector.flatten()], ["blue","red"])
plt.xlim(-0.5, 3)
plt.ylim(-0.5, 2)
# Out:
# [2 1]
# [1 2]
# (-0.5, 2.0)

# %%
print(np.linalg.det(A))
print(np.linalg.norm(vector))
print(np.linalg.norm(transformed_vector))
# Out:
# -4.0
# 2.23606797749979
# 2.23606797749979
